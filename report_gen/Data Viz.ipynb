# %%
# %load_ext autoreload
# %autoreload 1

# %%
# %aimport bluebonnet
import bluebonnet as bb
import plotly
import pandas as pd
plotly.offline.init_notebook_mode(connected=True)
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %% [markdown]
# # Bluebonnet Graph Generation Module Demo

# %%
"Run this code if you haven't run this notebook on your machine before"
#Builds out a dictionary of all of the State objects (WARNING: Takes a while, scrapes from 538)

house_cash = pd.read_csv('data/housesenate.txt',sep='|',header=None)
#states = bb.build_all(house_cash)

# %% [markdown]
# I've made it easy to load in all the data you want from a pickled binary structure containing the State and District objects. This is only a short-term solution and will be replaced as we setup our database. In the meantime, loading in a dictionary of all of the states is a single line,

# %%
states=bb.load('all_states.pickle')
states = bb.rebuild_fec(states,house_cash)
tx = states['TX']
ca = states['CA']

# %% [markdown]
# Now, let's say we want to generate all the graphs that we had in the March report in California. It's a simple one line instruction!

# %%
tx.gen_report()
# Out:
# <div id="1b2d6895-00b6-40dd-ba9a-034a259bb6ef" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("1b2d6895-00b6-40dd-ba9a-034a259bb6ef", [{"name": "Cash per voter", "x": ["16", "7", "32", "23", "31", "21", "2", "33", "29", "15", "36", "28", "22", "34", "6", "20", "18", "9", "35", "25", "10", "3", "30", "12", "27", "14", "26", "24", "1", "5", "19", "11", "8", "17", "4", "13"], "y": [54.19992258028839, 5.000307296709576, 3.604320511824172, 3.475647139975726, 2.8373030246349864, 2.274998765259408, 1.6485345394132607, 1.4708573802028682, 1.4396156456637137, 1.133383850717184, 1.0014147128349244, 0.9270650579689902, 0.7316130921247128, 0.6946029046990965, 0.6906080513253527, 0.6540764869654256, 0.6460074957256247, 0.638485304850217, 0.6136537691243988, 0.3583081626597659, 0.2966587631544758, 0.285851058708
# ...

# %%
bb.gen_full_pvi_scatter(states)
# Out:
# <div id="034b13f4-dfa3-437b-a929-b6bf4de714ea" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("034b13f4-dfa3-437b-a929-b6bf4de714ea", [{"mode": "markers", "x": [1.0, 1.0, 0.4358184185319326, 0.22393099294957122, 0.05034068709372119, 0.31793022065226934, 0.23902576324552266, 0.06389827856478761, 0.09867877545802212, 0.1640059945850993, 0.454701251574092, 0.11432592061049276, 0.9039921145470716, 0.7380237542239616, 1.0, 0.5669083620353541, 1.0, 0.30405467440760037, 0.9033467917294192, 0.31375634091762583, 0.6766459622946086, 0.9187182426135319, 0.6321129274927304, 0.7831187789577012, 1.0, 0.691979546927614, 0.8304529236193625, 0.8675392763735312, 0.7120180200290551, 1.0, 0.736816282976797, 0.4799371645149344, 0.9377616388953002, 0.9995464751971335, 0.7469410346660517, 0.9528714651447986, 0.5614351168
# ...
